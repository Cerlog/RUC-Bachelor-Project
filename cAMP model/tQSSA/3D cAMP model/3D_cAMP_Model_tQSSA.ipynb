# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
# if getting error, please mute the three lines below
mpl.rcParams.update(mpl.rcParamsDefault)
plt.rcParams.update({'text.usetex': True}) # import to make plots nicer
# %config InlineBackend.figure_format = 'svg' # import to make plots nicer
from scipy.integrate import solve_ivp
import numpy as np
from scipy.optimize import fsolve, approx_fprime
import matplotlib.pyplot as plt

# Set global font size for title, x-label, and y-label
plt.rcParams['axes.titlesize'] = 20

plt.rcParams['axes.labelsize'] = 16


# Set global font size for x and y tick labels
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16

# Set global font size for the legend
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['figure.figsize'] =  (8, 6)

# %%
def cAMP_PDEp_ACp_tQSSA(t, x):
    cAMP, PDEpt, ACpt = x
    dcAMP = k1*ACpt - (k2*PDEpt + k3)*cAMP
    dACPt = r1*cAMP*((W0 - ACpt)/(Km1 + cAMP + (W0 - ACpt))) - r2*Dt*ACpt/(Km2 + ACpt + Dt)
    dPDEpt = r3*cAMP*((W1 - PDEpt)/(Km3 + cAMP + (W1 - PDEpt))) - r4*Et*(PDEpt)/(Km4 + PDEpt + Et)
    return [dcAMP, dPDEpt, dACPt]


W0 = 10
W1 = 6.54
k = 0.4
k1, k3, k2 = 4.32/k, 0.58/k, 3.73/k
r1, r2, r3, r4 = 0.98/k, 4.48/k, 0.1/k, 0.14/k
Km1, Km2, Km3, Km4 = 2.48, 3.34, 9.24, 7.24
Dt, Et =  0.58, 1.6


x0 = [0.33, 0.33, 0.33]  # initial conditions

solver = solve_ivp(cAMP_PDEp_ACp_tQSSA, [0, 500], x0, t_eval=np.linspace(0, 500, 10000), method='RK45')

cAMP, PDEpt, ACpt = solver.y

fig = plt.figure(figsize=(16, 12))
fig.suptitle("3D Model - cAMP-PDEpt-ACpt Oscillations with tQSSA", fontsize=20, y=0.92)
gs = GridSpec(3, 2, figure=fig)
legend_position = {'bbox_to_anchor': (0.9, 1), 'loc': 'upper left'}

ax0 = fig.add_subplot(gs[0, 0])
ax0.grid(True, linestyle=':', color='lightgray')
ax0.plot(solver.t, cAMP, label='cAMP', color='#1f77b4')
ax0.set_xlabel('Time [min]')
ax0.set_ylabel('Concentration [nM]')
ax0.legend(**legend_position, fontsize=16)

ax1 = fig.add_subplot(gs[0, 1])
ax1.grid(True, linestyle=':', color='lightgray')
ax1.plot(solver.t, PDEpt, label='PDEpt', color='orange')
ax1.set_xlabel('Time [min]')
ax1.set_ylabel('Concentration [nM]')
ax1.legend(**legend_position, fontsize=16)

ax2 = fig.add_subplot(gs[1, 0])
ax2.grid(True, linestyle=':', color='lightgray')
ax2.plot(solver.t, ACpt, label='ACpt', color='green')
ax2.set_xlabel('Time [min]')
ax2.set_ylabel('Concentration [nM]')
ax2.legend(**legend_position, fontsize=16)

ax3 = fig.add_subplot(gs[1, 1])
ax3.grid(True, linestyle=':', color='lightgray')
ax3.plot(solver.t, cAMP, label='cAMP', color='#1f77b4', linestyle='-')
ax3.plot(solver.t, PDEpt, label='PDEpt', color='orange', linestyle='-', )
ax3.plot(solver.t, ACpt, label='ACpt', color='green', linestyle='--')
ax3.set_xlabel('Time [min]')
ax3.set_ylabel('Concentration [nM]')
ax3.legend(**legend_position, fontsize=16)

fig.subplots_adjust(wspace=0.3, hspace=0.4, right=0.85)
fig.savefig('cAMP_PDEp_ACp.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      17 Dt, Et =  0.58, 1.6
#      20 x0 = [0.33, 0.33, 0.33]  # initial conditions
# ---> 22 solver = solve_ivp(cAMP_PDEp_ACp_tQSSA, [0, 500], x0, t_eval=np.linspace(0, 500, 10000), method='RK45')
#      24 cAMP, PDEpt, ACpt = solver.y
#      26 fig = plt.figure(figsize=(16, 12))
#
# NameError: name 'solve_ivp' is not defined

# %%
fig_3d = plt.figure(figsize=(10, 10))
ax_3d = fig_3d.add_subplot(111, projection='3d')
plt.subplots_adjust(top=0.85)

ax_3d.plot(cAMP, PDEpt, ACpt, label='cAMP-PDEpt-ACpt limit cycle', color='black', linestyle='-', linewidth=2, alpha=0.7, marker='o', markersize=5)
ax_3d.set_title('Limit cycle of the cAMP-PDEp-ACp oscillations with tQSSA', y=1)
ax_3d.set_xlabel('cAMP', fontsize=16, labelpad=5)
ax_3d.set_ylabel('PDEp', fontsize=16, labelpad=5)
ax_3d.set_zlabel('ACp', fontsize=16, labelpad=-1)

ax_3d.legend(fontsize=16, bbox_to_anchor=(1, 0.9))


ax_3d.view_init(15,150)
ax_3d.set_box_aspect([1, 1, 1])
ax_3d.grid(True, linestyle=':', color='lightgray')

plt.savefig('3DcAMP_PDEp_ACp.png_limit_cycle_tQSSA.png', dpi=300, bbox_inches='tight')
plt.show()
